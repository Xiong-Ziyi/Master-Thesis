# %% [markdown]
# # **Beam Shaper**

# %%
from pprint import pprint
from classes.beam_shaper import BeamShaper
  
beamshaper = BeamShaper(
    omega=2.366,
    R_max=4.05,
    r_max=4.05,
    d=150.0,
    n=1.46071,
    type="Galilean",
    approx=True,)

pprint(beamshaper.result)
# Out:
# {'k_1': -1177.8672663234013,
#  'k_2': -487.1247307414178,
#  'r_c1': 48.521746897938684,
#  'r_c2': 117.62824689793868}

# %% [markdown]
# # **Fermi-Dirac**

# %%
from classes.fermi_dirac import FermiDirac

# %%
fermidirac = FermiDirac(R_max=4.05, beta=10, num_samples=100)
fermidirac.plot()

# %%
fermidirac2 = FermiDirac(R_max=4.05, beta=20, num_samples=100)
fermidirac2.plot()

# %% [markdown]
# # **Super Gaussian**

# %%
from classes.super_gaussian import SuperGaussianIntensity

supergaussian = SuperGaussianIntensity(
    Intensity=1,
    center=0,
    width=8,
    max_coord=10, 
    order=10, 
    num_samples=100)

supergaussian.plot()
